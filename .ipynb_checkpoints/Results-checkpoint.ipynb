# %%
import pandas as pd
df = pd.read_csv('results.csv').drop('Unnamed: 0',axis=1)
#df2 = pd.read_csv('results_after_cleaning.csv').drop('Unnamed: 0',axis=1)
df.head()
# Out:
#    F1 score  accuracy score                model      time  features
# 0  0.899522        0.896637  Logistic Regression  0.005567         1
# 1  0.899522        0.896637        Decision Tree  0.002767         1
# 2  0.899522        0.896637        Random Forest  0.046762         1
# 3  0.899522        0.896637  K-Nearest Neighbors  0.057864         1
# 4  0.899522        0.896637                  SVM  0.634260         1

# %%
df[df['accuracy score']>0.99]
# Out:
#      F1 score  accuracy score                model      time  features
# 81   0.992751        0.993027        Decision Tree  0.003773        17
# 82   0.992751        0.993027        Random Forest  0.051759        17
# 83   0.992751        0.993027  K-Nearest Neighbors  0.118114        17
# 86   0.995723        0.995898        Decision Tree  0.003900        18
# 87   0.995723        0.995898        Random Forest  0.050370        18
# 88   0.995723        0.995898  K-Nearest Neighbors  0.121749        18
# 91   1.000000        1.000000        Decision Tree  0.004031        19
# 92   1.000000        1.000000        Random Forest  0.050118        19
# 93   1.000000        1.000000  K-Nearest Neighbors  0.124985        19
# 94   0.997416        0.997539                  SVM  0.380783        19
# 96   1.000000        1.000000        Decision Tree  0.003972        20
# 97   1.000000        1.000000        Random Forest  0.050559        20
# 98   1.000000        1.000000  K-Nearest Neighbors  0.126732        20
# 99   0.997848        0.997949                  SVM  0.357429        20
# 101  1.000000        1.000000        Decision Tree  0.004141        21
# 102  1.000000        1.000000        Random Forest  0.051084        21
# 103  1.000000        1.000000  K-Nearest Neighbors  0.134699        21
# 104  0.997416        0.997539                  SVM  0.381922        21
# 106  1.000000        1.000000        Decision Tree  0.004195        22
# 107  1.000000        1.000000        Random Forest  0.051159        22
# 108  1.000000        1.000000  K-Nearest Neighbors  0.141247        22
# 109  0.997416        0.997539                  SVM  0.434182        22
# 111  1.000000        1.000000        Decision Tree  0.004252        23
# 112  1.000000        1.000000        Random Forest  0.052756        23
# 113  1.000000        1.000000  K-Nearest Neighbors  0.142043        23
# 114  0.997416        0.997539                  SVM  0.472939        23
# 116  1.000000        1.000000        Decision Tree  0.004340        24
# 117  1.000000        1.000000        Random Forest  0.051646        24
# 118  1.000000        1.000000  K-Nearest Neighbors  0.143077        24
# 119  0.997416        0.997539                  SVM  0.465489        24
# ..        ...             ...                  ...       ...       ...
# 525  0.997848        0.997949  Logistic Regression  0.028298       106
# 526  1.000000        1.000000        Decision Tree  0.013417       106
# 527  1.000000        1.000000        Random Forest  0.076732       106
# 528  1.000000        1.000000  K-Nearest Neighbors  0.740194       106
# 529  1.000000        1.000000                  SVM  6.974472       106
# 530  0.997848        0.997949  Logistic Regression  0.027616       107
# 531  1.000000        1.000000        Decision Tree  0.013516       107
# 532  1.000000        1.000000        Random Forest  0.073939       107
# 533  1.000000        1.000000  K-Nearest Neighbors  0.749003       107
# 534  1.000000        1.000000                  SVM  7.095083       107
# 535  0.997848        0.997949  Logistic Regression  0.031437       108
# 536  1.000000        1.000000        Decision Tree  0.013282       108
# 537  1.000000        1.000000        Random Forest  0.073232       108
# 538  1.000000        1.000000  K-Nearest Neighbors  0.751236       108
# 539  1.000000        1.000000                  SVM  7.194024       108
# 540  0.997848        0.997949  Logistic Regression  0.027611       109
# 541  1.000000        1.000000        Decision Tree  0.013638       109
# 542  1.000000        1.000000        Random Forest  0.072478       109
# 543  1.000000        1.000000  K-Nearest Neighbors  0.767623       109
# 544  1.000000        1.000000                  SVM  7.258794       109
# 545  0.998710        0.998769  Logistic Regression  0.027657       110
# 546  1.000000        1.000000        Decision Tree  0.014128       110
# 547  1.000000        1.000000        Random Forest  0.071650       110
# 548  1.000000        1.000000  K-Nearest Neighbors  0.770202       110
# 549  1.000000        1.000000                  SVM  7.287672       110
# 550  0.998710        0.998769  Logistic Regression  0.027664       111
# 551  1.000000        1.000000        Decision Tree  0.014282       111
# 552  1.000000        1.000000        Random Forest  0.073125       111
# 553  1.000000        1.000000  K-Nearest Neighbors  0.776435       111
# 554  1.000000        1.000000                  SVM  7.343308       111
#
# [452 rows x 5 columns]

# %%
df.groupby(by='features').mean()
# Out:
#           F1 score  accuracy score      time
# features
# 1         0.847943        0.899646  0.065871
# 2         0.847943        0.899646  0.066729
# 3         0.847943        0.899646  0.083890
# 4         0.860177        0.906730  0.086231
# 5         0.860177        0.906730  0.089523
# 6         0.860177        0.906730  0.094429
# 7         0.850193        0.881228  0.100280
# 8         0.850193        0.881228  0.104885
# 9         0.849536        0.880638  0.111440
# 10        0.867754        0.898701  0.115318
# 11        0.868076        0.897521  0.120417
# 12        0.870665        0.898819  0.123022
# 13        0.880384        0.905903  0.129217
# 14        0.880384        0.905903  0.132073
# 15        0.880442        0.906021  0.137027
# 16        0.880442        0.906021  0.139010
# 17        0.928770        0.948642  0.108351
# 18        0.928770        0.948642  0.109086
# 19        0.929273        0.948996  0.107138
# 20        0.921265        0.939079  0.114812
# 21        0.917702        0.935419  0.126657
# 22        0.991985        0.993861  0.074158
# 23        0.991985        0.993861  0.089001
# 24        0.991985        0.993861  0.080157
# 25        0.992296        0.994097  0.078129
# 26        0.992296        0.994097  0.077075
# 27        0.992296        0.994097  0.085379
# 28        0.992296        0.994097  0.094597
# 29        0.992296        0.994097  0.083893
# 30        1.000000        1.000000  0.088173
# ...            ...             ...       ...
# 56        1.000000        1.000000  0.261704
# 57        1.000000        1.000000  0.299487
# 58        1.000000        1.000000  0.296191
# 59        1.000000        1.000000  0.280678
# 60        1.000000        1.000000  0.325254
# 61        1.000000        1.000000  0.271176
# 62        1.000000        1.000000  0.297080
# 63        1.000000        1.000000  0.323305
# 64        1.000000        1.000000  0.469646
# 65        1.000000        1.000000  0.355224
# 66        1.000000        1.000000  0.391336
# 67        1.000000        1.000000  0.458420
# 68        1.000000        1.000000  0.393041
# 69        1.000000        1.000000  0.379081
# 70        1.000000        1.000000  0.411110
# 71        1.000000        1.000000  0.381140
# 72        1.000000        1.000000  0.352711
# 73        1.000000        1.000000  0.361853
# 74        1.000000        1.000000  0.371990
# 75        1.000000        1.000000  0.380407
# 76        1.000000        1.000000  0.458513
# 77        1.000000        1.000000  0.493227
# 78        1.000000        1.000000  0.493498
# 79        1.000000        1.000000  0.455692
# 80        1.000000        1.000000  0.568525
# 81        1.000000        1.000000  0.450403
# 82        1.000000        1.000000  0.580575
# 83        1.000000        1.000000  0.535268
# 84        1.000000        1.000000  0.504583
# 85        1.000000        1.000000  0.647894
#
# [85 rows x 3 columns]

# %%
log_reg = df[df['model']=='Logistic Regression'][['features','F1 score','accuracy score','time']]
dt = df[df['model']=='Decision Tree'][['features','F1 score','accuracy score','time']]
rf = df[df['model']=='Random Forest'][['features','F1 score','accuracy score','time']]
knn = df[df['model']=='K-Nearest Neighbors'][['features','F1 score','accuracy score','time']]
svm = df[df['model']=='Linear SVM'][['features','F1 score','accuracy score','time']]

# %%
import matplotlib.pyplot as plt
import numpy as np
x = df['features']
plt.figure(figsize=(10,10))
plt.subplot(3,1,1)
plt.plot(log_reg['features'],log_reg['accuracy score'],label='Log Reg')
plt.plot(dt['features'],dt['accuracy score'],label='Decision Tree')
plt.plot(rf['features'],rf['accuracy score'],label='Random Forest')
plt.plot(knn['features'],knn['accuracy score'],label='KNN')
plt.plot(svm['features'],svm['accuracy score'],label='SVM')
plt.legend()
plt.ylabel('accuracy')
plt.xlabel('Number of features used')
plt.title("Number of features used to model vs accuracy score")
plt.xticks(np.arange(min(x), max(x)+1, 5.0))
### F1 score plot
plt.subplot(3,1,2)
plt.plot(log_reg['features'],log_reg['F1 score'],label='Log Reg')
plt.plot(dt['features'],dt['F1 score'],label='Decision Tree')
plt.plot(rf['features'],rf['F1 score'],label='Random Forest')
plt.plot(knn['features'],knn['F1 score'],label='KNN')
plt.plot(svm['features'],svm['F1 score'],label='SVM')
plt.legend()
plt.ylabel('F1 Score')
plt.xlabel('Number of features used')
plt.title("Number of features used to model vs F1 Score")
plt.xticks(np.arange(min(x), max(x)+1, 5.0))
plt.subplots_adjust(hspace=0.4)
### Time
plt.subplot(3,1,3)
plt.plot(log_reg['features'],log_reg['time'],label='Log Reg')
plt.plot(dt['features'],dt['time'],label='Decision Tree')
plt.plot(rf['features'],rf['time'],label='Random Forest')
plt.plot(knn['features'],knn['time'],label='KNN')
plt.plot(svm['features'],svm['time'],label='SVM')
plt.legend()
plt.ylabel('time (s)')
plt.xlabel('Number of features used')
plt.title("Number of Features used vs Training + Predicting time for each model")
plt.xticks(np.arange(min(x), max(x)+1, 5.0))
plt.subplots_adjust(hspace=0.4)
plt.show()

# %%
knn
# Out:
#     features  F1 score  accuracy score      time
# 3        113  1.000000        1.000000  2.517847
# 8         59  1.000000        1.000000  0.587725
# 13        44  1.000000        1.000000  0.199991
# 18        27  1.000000        1.000000  0.141692
# 23        22  1.000000        1.000000  0.124074
# 28        18  0.993598        0.993847  0.112495
# 33        16  0.976118        0.977441  0.107355
# 38        13  0.975986        0.977030  0.089225
# 43        10  0.975986        0.977030  0.077778
# 48         8  0.925704        0.933962  0.084707
# 53         7  0.975107        0.976210  0.080424
# 58         5  0.925704        0.933962  0.064459
# 63         7  0.975107        0.976210  0.076907
# 68         5  0.925704        0.933962  0.068438
# 73         4  0.871546        0.891304  0.069584
# 78         2  0.887135        0.882691  0.057162
# 83         1  0.887135        0.882691  0.062210
# 88         1  0.887135        0.882691  0.063164

# %%
import numpy as np
data = pd.read_csv('prepared_data.csv').drop('Unnamed: 0',axis=1)
corr = data.corr()['class']
corr = pd.DataFrame(corr).reset_index().rename(columns={'index':'Feature','class':'Correlation with target'})
corr['absolute'] = corr['Correlation with target'].apply(lambda x:np.abs(x))
corr = corr.sort_values(by='absolute',ascending=False).reset_index().drop('index',axis=1).drop('absolute',axis=1)
corr = corr.loc[1:]
corr.to_csv('key_features.csv')
corr
# Out:
#                         Feature  Correlation with target
# 1                        odor_n                -0.785557
# 2                        odor_f                 0.623842
# 3    stalk-surface-above-ring_k                 0.587658
# 4    stalk-surface-below-ring_k                 0.573524
# 5                   ring-type_p                -0.540469
# 6                   gill-size_n                 0.540024
# 7                   gill-size_b                -0.540024
# 8                  gill-color_b                 0.538808
# 9                     bruises_f                 0.501530
# 10                    bruises_t                -0.501530
# 11   stalk-surface-above-ring_s                -0.491314
# 12          spore-print-color_h                 0.490229
# 13                  ring-type_l                 0.451619
# 14                 population_v                 0.443722
# 15   stalk-surface-below-ring_s                -0.425444
# 16          spore-print-color_n                -0.416645
# 17          spore-print-color_k                -0.396832
# 18          spore-print-color_w                 0.357384
# 19               gill-spacing_c                 0.348387
# 20               gill-spacing_w                -0.348387
# 21                    habitat_p                 0.323346
# 22                 gill-color_n                -0.288943
# 23                       odor_s                 0.286360
# 24                       odor_y                 0.286360
# 25     stalk-color-above-ring_g                -0.266489
# 26     stalk-color-below-ring_g                -0.266489
# 27     stalk-color-below-ring_b                 0.245662
# 28     stalk-color-above-ring_b                 0.245662
# 29     stalk-color-above-ring_n                 0.233164
# 30                 gill-color_w                -0.231316
# ..                          ...                      ...
# 82                cap-surface_s                 0.095454
# 83                cap-surface_y                 0.088677
# 84                 gill-color_o                -0.085962
# 85   stalk-surface-below-ring_y                -0.081674
# 86          spore-print-color_o                -0.074371
# 87          spore-print-color_y                -0.074371
# 88          spore-print-color_b                -0.074371
# 89          spore-print-color_u                -0.074371
# 90                  ring-type_f                -0.074371
# 91     stalk-color-above-ring_c                 0.069159
# 92                  ring-type_n                 0.069159
# 93                ring-number_n                 0.069159
# 94     stalk-color-below-ring_c                 0.069159
# 95                       odor_m                 0.069159
# 96                  cap-color_b                 0.067544
# 97                  cap-shape_s                -0.060664
# 98                 gill-color_r                 0.056426
# 99     stalk-color-below-ring_y                 0.056426
# 100                gill-color_p                -0.050380
# 101                gill-color_y                -0.046828
# 102                 cap-color_g                -0.046456
# 103                 cap-color_n                -0.044360
# 104                 cap-color_u                -0.042854
# 105                 cap-color_r                -0.042854
# 106                 cap-color_p                 0.034702
# 107                veil-color_y                 0.032545
# 108    stalk-color-above-ring_y                 0.032545
# 109                 cap-color_c                -0.030910
# 110               cap-surface_g                 0.023007
# 111                 cap-shape_c                 0.023007
#
# [111 rows x 2 columns]
